# %%
from meta_comparers import compare_risks_meta

# %%
meta_models = ['sl', 'tl']
base_models = ['l1', 'l2', 'dt', 'rf', 'et', 'kr', 'cb', 'lgbm']
cate_models = ['cf']
base_metrics_dir = '../results/metrics/run2/'

plugin_meta_models = ['sl', 'tl']
plugin_base_models = ['dt', 'lgbm', 'cb']
plugin_models = [f'{pmm}_{pbm}' for pmm in plugin_meta_models for pbm in plugin_base_models]
plugin_dir = '../results/scores/run1/'

rscore_base_models = ['dt', 'lgbm', 'cb']
rscore_dir = '../results/scores/run1/'

# %%
df_all = compare_risks_meta(cate_models, meta_models, base_models, plugin_models, rscore_base_models, base_metrics_dir, plugin_dir, rscore_dir)

# %%
metric = 'ate'
p_metric = 'pehe'
plugin_cols = [f'{metric}_{pm}_{p_metric}' for pm in plugin_models]
rscore_cols = [f'{metric}_rs_{rs_bm}' for rs_bm in rscore_base_models]
cols = ['name', f'{metric}_mse', f'{metric}_r2'] + plugin_cols + rscore_cols
df_all[cols]
# Out:
#   name          ate_mse           ate_r2   ate_sl_dt_pehe ate_sl_lgbm_pehe  \
# 0   sl  4.789 +/- 2.708  0.183 +/- 0.155  1.691 +/- 3.791  4.789 +/- 2.708
# 1   tl  0.168 +/- 0.293  0.180 +/- 0.288  1.725 +/- 3.780  4.791 +/- 2.711
# 2   cf                -                -  0.095 +/- 0.196  0.100 +/- 0.193
#
#     ate_sl_cb_pehe   ate_tl_dt_pehe ate_tl_lgbm_pehe   ate_tl_cb_pehe  \
# 0  1.661 +/- 1.723  0.144 +/- 0.115  0.301 +/- 0.352  0.313 +/- 0.469
# 1  1.600 +/- 1.426  0.395 +/- 0.503  0.230 +/- 0.389  0.233 +/- 0.382
# 2  0.093 +/- 0.192  0.029 +/- 0.031  0.074 +/- 0.130  0.029 +/- 0.042
#
#          ate_rs_dt      ate_rs_lgbm        ate_rs_cb
# 0  1.048 +/- 0.493  0.317 +/- 0.183  0.594 +/- 0.246
# 1  0.968 +/- 0.393  0.202 +/- 0.203  0.335 +/- 0.248
# 2  0.040 +/- 0.078  0.042 +/- 0.078  0.041 +/- 0.078

# %%
metric = 'pehe'
p_metric = 'pehe'
plugin_cols = [f'{metric}_{pm}_{p_metric}' for pm in plugin_models]
rscore_cols = [f'{metric}_rs_{rs_bm}' for rs_bm in rscore_base_models]
cols = ['name', f'{metric}_mse', f'{metric}_r2'] + plugin_cols + rscore_cols
df_all[cols]
# Out:
#   name         pehe_mse          pehe_r2  pehe_sl_dt_pehe pehe_sl_lgbm_pehe  \
# 0   sl  2.618 +/- 0.875  1.560 +/- 2.696  0.418 +/- 0.485   2.619 +/- 0.875
# 1   tl  1.746 +/- 2.917  1.748 +/- 2.916  0.519 +/- 0.837   2.638 +/- 0.813
# 2   cf                -                -  0.020 +/- 0.028   0.014 +/- 0.011
#
#    pehe_sl_cb_pehe  pehe_tl_dt_pehe pehe_tl_lgbm_pehe  pehe_tl_cb_pehe  \
# 0  0.557 +/- 0.263  0.715 +/- 0.845   0.569 +/- 0.965  0.643 +/- 1.024
# 1  0.513 +/- 0.366  0.726 +/- 1.157   0.805 +/- 1.494  0.742 +/- 1.292
# 2  0.032 +/- 0.030  0.136 +/- 0.185   0.130 +/- 0.265  0.187 +/- 0.308
#
#         pehe_rs_dt     pehe_rs_lgbm       pehe_rs_cb
# 0  1.359 +/- 1.395  1.145 +/- 1.498  1.481 +/- 2.036
# 1  1.435 +/- 1.972  1.583 +/- 2.853  1.590 +/- 2.507
# 2  0.206 +/- 0.297  0.211 +/- 0.295  0.208 +/- 0.296
