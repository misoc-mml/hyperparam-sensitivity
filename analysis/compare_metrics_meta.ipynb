# %%
import pandas as pd

plugin_meta_models = ['sl', 'tl']
plugin_base_models = ['dt', 'lgbm', 'cb']
plugin_models = [f'{pmm}_{pbm}' for pmm in plugin_meta_models for pbm in plugin_base_models]
rscore_base_models = ['dt', 'lgbm', 'cb']

df_all = pd.read_csv('./tables/compare_metrics_meta.csv')

# %%
metric = 'ate'
p_metric = 'pehe'
plugin_cols = [f'{metric}_{pm}_{p_metric}' for pm in plugin_models]
rscore_cols = [f'{metric}_rs_{rs_bm}' for rs_bm in rscore_base_models]
cols = ['name', f'{metric}_mse', f'{metric}_r2'] + plugin_cols + rscore_cols + [f'{metric}_test']
df_all[cols]
# Out:
#   name          ate_mse           ate_r2   ate_sl_dt_pehe ate_sl_lgbm_pehe  \
# 0   sl  4.791 +/- 2.711  0.184 +/- 0.155  1.692 +/- 3.794  4.791 +/- 2.711
# 1   tl  0.168 +/- 0.293  0.180 +/- 0.288  1.725 +/- 3.780  4.791 +/- 2.711
# 2   cf                -                -  0.294 +/- 0.586  0.299 +/- 0.583
#
#     ate_sl_cb_pehe   ate_tl_dt_pehe ate_tl_lgbm_pehe   ate_tl_cb_pehe  \
# 0  1.662 +/- 1.725  0.146 +/- 0.115  0.303 +/- 0.353  0.314 +/- 0.469
# 1  1.600 +/- 1.426  0.395 +/- 0.503  0.230 +/- 0.389  0.233 +/- 0.382
# 2  0.292 +/- 0.582  0.227 +/- 0.385  0.273 +/- 0.521  0.228 +/- 0.386
#
#          ate_rs_dt      ate_rs_lgbm        ate_rs_cb         ate_test
# 0  1.050 +/- 0.495  0.318 +/- 0.185  0.596 +/- 0.247  0.001 +/- 0.003
# 1  0.968 +/- 0.393  0.202 +/- 0.203  0.335 +/- 0.248  0.000 +/- 0.000
# 2  0.239 +/- 0.389  0.240 +/- 0.388  0.240 +/- 0.388  0.198 +/- 0.392

# %%
metric = 'pehe'
p_metric = 'pehe'
plugin_cols = [f'{metric}_{pm}_{p_metric}' for pm in plugin_models]
rscore_cols = [f'{metric}_rs_{rs_bm}' for rs_bm in rscore_base_models]
cols = ['name', f'{metric}_mse', f'{metric}_r2'] + plugin_cols + rscore_cols + [f'{metric}_test']
df_all[cols]
# Out:
#   name         pehe_mse          pehe_r2  pehe_sl_dt_pehe pehe_sl_lgbm_pehe  \
# 0   sl  6.998 +/- 6.783  5.940 +/- 9.937  4.797 +/- 7.714   6.998 +/- 6.783
# 1   tl  6.107 +/- 9.793  6.109 +/- 9.791  4.879 +/- 7.686   6.998 +/- 6.783
# 2   cf                -                -  4.853 +/- 7.830   4.847 +/- 7.830
#
#    pehe_sl_cb_pehe  pehe_tl_dt_pehe pehe_tl_lgbm_pehe  pehe_tl_cb_pehe  \
# 0  4.936 +/- 7.091  5.094 +/- 8.038   4.949 +/- 8.199  5.023 +/- 8.262
# 1  4.874 +/- 6.944  5.086 +/- 8.029   5.166 +/- 8.365  5.102 +/- 8.164
# 2  4.865 +/- 7.824  4.969 +/- 7.973   4.963 +/- 8.097  5.020 +/- 8.133
#
#         pehe_rs_dt     pehe_rs_lgbm       pehe_rs_cb        pehe_test
# 0  5.739 +/- 8.634  5.525 +/- 8.732  5.861 +/- 9.273  4.379 +/- 7.246
# 1  5.796 +/- 8.824  5.944 +/- 9.718  5.950 +/- 9.377  4.360 +/- 6.878
# 2  5.039 +/- 8.121  5.044 +/- 8.119  5.042 +/- 8.120  4.833 +/- 7.833
