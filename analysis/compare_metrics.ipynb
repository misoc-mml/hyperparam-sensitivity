# %%
import pandas as pd

plugin_meta_models = ['sl', 'tl']
plugin_base_models = ['dt', 'lgbm', 'cb']
plugin_models = [f'{pmm}_{pbm}' for pmm in plugin_meta_models for pbm in plugin_base_models]
rscore_base_models = ['dt', 'lgbm', 'cb']

df_all = pd.read_csv('./tables/compare_metrics.csv')

# %%
metric = 'ate'
p_metric = 'pehe'
plugin_cols = [f'{metric}_{pm}_{p_metric}' for pm in plugin_models]
rscore_cols = [f'{metric}_rs_{rs_bm}' for rs_bm in rscore_base_models]
cols = ['name', f'{metric}_mse', f'{metric}_r2'] + plugin_cols + rscore_cols + [f'{metric}_test']
df_all[cols]
# Out:
#        name          ate_mse           ate_r2   ate_sl_dt_pehe  \
# 0     sl_l1  4.791 +/- 2.711  1.241 +/- 2.676  1.730 +/- 3.781
# 1     sl_l2  1.676 +/- 2.643  1.262 +/- 2.780  1.165 +/- 2.807
# 2     sl_dt  0.388 +/- 0.807  0.411 +/- 0.637  0.422 +/- 0.802
# 3     sl_rf  0.986 +/- 2.165  0.267 +/- 0.456  1.246 +/- 2.946
# 4     sl_et  0.914 +/- 2.423  0.239 +/- 0.338  0.892 +/- 2.431
# 5     sl_kr  4.791 +/- 2.711  0.198 +/- 0.128  1.665 +/- 3.805
# 6     sl_cb  1.317 +/- 1.364  0.338 +/- 0.163  0.757 +/- 1.543
# 7   sl_lgbm  0.193 +/- 0.186  0.193 +/- 0.184  0.192 +/- 0.171
# 8     tl_l1  0.461 +/- 0.450  0.461 +/- 0.450  1.913 +/- 3.715
# 9     tl_l2  0.470 +/- 0.524  0.466 +/- 0.516  0.530 +/- 0.666
# 10    tl_dt  0.247 +/- 0.197  0.247 +/- 0.200  0.265 +/- 0.385
# 11    tl_rf  0.148 +/- 0.148  0.141 +/- 0.148  0.282 +/- 0.485
# 12    tl_et  0.259 +/- 0.616  0.331 +/- 0.821  0.317 +/- 0.478
# 13    tl_kr  0.174 +/- 0.292  0.175 +/- 0.291  1.681 +/- 3.798
# ...

# %%
metric = 'pehe'
p_metric = 'pehe'
plugin_cols = [f'{metric}_{pm}_{p_metric}' for pm in plugin_models]
rscore_cols = [f'{metric}_rs_{rs_bm}' for rs_bm in rscore_base_models]
cols = ['name', f'{metric}_mse', f'{metric}_r2'] + plugin_cols + rscore_cols + [f'{metric}_test']
df_all[cols]
# Out:
#        name         pehe_mse           pehe_r2  pehe_sl_dt_pehe  \
# 0     sl_l1  6.998 +/- 6.783   4.428 +/- 7.332  4.609 +/- 7.793
# 1     sl_l2  4.647 +/- 7.271   4.440 +/- 7.367  4.425 +/- 7.371
# 2     sl_dt  4.875 +/- 7.756   5.466 +/- 8.428  4.917 +/- 7.738
# 3     sl_rf  4.596 +/- 7.213   5.276 +/- 8.185  4.687 +/- 7.362
# 4     sl_et  4.607 +/- 7.275   5.511 +/- 8.704  4.659 +/- 7.254
# 5     sl_kr  6.998 +/- 6.783  5.787 +/- 10.065  4.734 +/- 7.741
# 6     sl_cb  5.484 +/- 8.139   5.546 +/- 8.749  5.238 +/- 8.247
# 7   sl_lgbm  5.625 +/- 8.867   5.682 +/- 9.051  5.607 +/- 8.937
# 8     tl_l1  5.910 +/- 9.286   5.910 +/- 9.286  4.916 +/- 7.661
# 9     tl_l2  5.819 +/- 9.259   5.773 +/- 9.145  5.619 +/- 8.999
# 10    tl_dt  5.802 +/- 9.038   5.781 +/- 9.024  5.262 +/- 8.208
# 11    tl_rf  5.600 +/- 8.819   5.592 +/- 8.823  5.015 +/- 7.993
# 12    tl_et  5.812 +/- 9.316   5.910 +/- 9.554  4.868 +/- 7.668
# 13    tl_kr  6.113 +/- 9.790   6.113 +/- 9.790  4.873 +/- 7.689
# ...

# %%
metric = 'ate'
p_metric = 'ate'
plugin_cols = [f'{metric}_{pmm}_{pbm}_{p_metric}' for pmm in plugin_meta_models for pbm in plugin_base_models]
rscore_cols = [f'{metric}_rs_{rs_bm}' for rs_bm in rscore_base_models]
cols = ['name', f'{metric}_mse', f'{metric}_r2'] + plugin_cols + rscore_cols + [f'{metric}_test']
df_all[cols]

# %%
metric = 'pehe'
p_metric = 'ate'
plugin_cols = [f'{metric}_{pmm}_{pbm}_{p_metric}' for pmm in plugin_meta_models for pbm in plugin_base_models]
rscore_cols = [f'{metric}_rs_{rs_bm}' for rs_bm in rscore_base_models]
cols = ['name', f'{metric}_mse', f'{metric}_r2'] + plugin_cols + rscore_cols + [f'{metric}_test']
df_all[cols]
