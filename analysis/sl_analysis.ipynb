# %%
import numpy as np
import pandas as pd

from utils import load_merge, get_mse_corr, get_risk

# %%
path = '../results/metrics/'

meta_model = 'sl'
base_models = ['l1', 'l2', 'dt', 'rf', 'et', 'kr', 'cb', 'lgbm']

mse_corr_list = []
risk_list = []

# %%
for b_m in base_models:
    main_df = load_merge(path, f'{meta_model}_{b_m}')

    corr_i = get_mse_corr(main_df)
    mse_corr_list.append([f'{meta_model}-{b_m}'] + corr_i)

    r_ate, r_pehe = get_risk(main_df)
    risk_list.append([f'{meta_model}-{b_m}'] + r_ate + r_pehe)

# %%
df_corr = pd.DataFrame(mse_corr_list, columns=['name', 'ate_val', 'pehe_val', 'mse_test', 'ate_test', 'pehe_test'])

# %%
df_corr
# Out:
#       name           ate_val          pehe_val         mse_test  \
# 0    sl-l1  -0.980 +/- 0.022  -0.972 +/- 0.020  0.999 +/- 0.002
# 1    sl-l2  -0.998 +/- 0.004  -0.991 +/- 0.008  1.000 +/- 0.000
# 2    sl-dt   0.266 +/- 0.474   0.964 +/- 0.023  0.860 +/- 0.079
# 3    sl-rf  -0.389 +/- 0.521   0.916 +/- 0.105  0.947 +/- 0.059
# 4    sl-et  -0.201 +/- 0.593   0.956 +/- 0.037  0.977 +/- 0.029
# 5    sl-kr  -0.721 +/- 0.140  -0.227 +/- 0.523  0.820 +/- 0.115
# 6    sl-cb  -0.970 +/- 0.026  -0.518 +/- 0.720  0.967 +/- 0.013
# 7  sl-lgbm   0.023 +/- 0.319   0.189 +/- 0.359  0.260 +/- 0.252
#
#            ate_test         pehe_test
# 0  -0.978 +/- 0.023  -0.970 +/- 0.019
# 1  -0.787 +/- 0.597  -0.779 +/- 0.593
# 2   0.130 +/- 0.427   0.884 +/- 0.090
# 3  -0.033 +/- 0.492   0.792 +/- 0.311
# 4  -0.069 +/- 0.591   0.909 +/- 0.096
# 5  -0.708 +/- 0.130  -0.287 +/- 0.551
# 6  -0.942 +/- 0.083  -0.528 +/- 0.656
# 7  -0.017 +/- 0.285   0.081 +/- 0.271

# %%
df_risk = pd.DataFrame(risk_list, columns=['name', 'ate_risk', 'pehe_risk'])

# %%
df_risk
# Out:
#       name         ate_risk        pehe_risk
# 0    sl-l1  3.654 +/- 0.446  2.584 +/- 0.909
# 1    sl-l2  0.576 +/- 0.212  0.242 +/- 0.135
# 2    sl-dt  0.380 +/- 0.794  0.038 +/- 0.065
# 3    sl-rf  0.943 +/- 2.168  0.025 +/- 0.027
# 4    sl-et  0.808 +/- 2.143  0.074 +/- 0.093
# 5    sl-kr  4.747 +/- 2.710  2.574 +/- 0.865
# 6    sl-cb  1.108 +/- 1.252  0.277 +/- 0.136
# 7  sl-lgbm  0.087 +/- 0.074  0.053 +/- 0.035
