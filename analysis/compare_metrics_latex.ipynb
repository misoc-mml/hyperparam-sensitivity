# %%
import pandas as pd

# %%
def show(df, metric, plugin_metric, plugin_models, rscore_models):
    plugin_cols = [f'{metric}_{pm}_{plugin_metric}' for pm in plugin_models]
    rscore_cols = [f'{metric}_rs_{rs_bm}' for rs_bm in rscore_models]
    cols = ['name', f'{metric}_mse', f'{metric}_r2', f'{metric}_mixed'] + plugin_cols + rscore_cols + [f'{metric}_test']
    return df[cols]

# %% [markdown]
# ## IHDP

# %%
plugin_meta_models = ['sl', 'tl']
#plugin_base_models = ['dt', 'lgbm', 'cb']
plugin_base_models = ['lgbm']
plugin_models = [f'{pmm}_{pbm}' for pmm in plugin_meta_models for pbm in plugin_base_models]
#rscore_base_models = ['dt', 'lgbm', 'cb']
rscore_base_models = ['lgbm']

ds = 'ihdp'
df_all = pd.read_csv(f'./tables/{ds}_compare_metrics_latex.csv')
avg_metric = 'ate'
ite_metric = 'pehe'

df_all['name'] = df_all['name'].apply(lambda x: x.upper().replace('_', '-'))

# %%
df_ate = show(df_all, avg_metric, 'ate', plugin_models, rscore_base_models)
df_pehe = show(df_all, ite_metric, 'pehe', plugin_models, rscore_base_models)
#df

# %%
def my_filter(x, metric):
    if x[f'{metric}_mse'] != '-':
        return x[f'{metric}_mse']
    elif x[f'{metric}_mixed'] != '-':
        return x[f'{metric}_mixed']
    else:
        return x[f'{metric}_rs_lgbm']

def ate_filter(x):
    return my_filter(x, 'ate')

def pehe_filter(x):
    return my_filter(x, 'pehe')

def att_filter(x):
    return my_filter(x, 'att')

def policy_filter(x):
    return my_filter(x, 'policy')

# %%
df_ate['selection'] = df_ate.apply(ate_filter, axis=1)
df_pehe['selection'] = df_pehe.apply(pehe_filter, axis=1)
#df[['name', 'selection', f'{avg_metric}_test']]
# Out:
# <ipython-input-6-5a9d6fd8ce03>:1: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df_ate['selection'] = df_ate.apply(ate_filter, axis=1)
# <ipython-input-6-5a9d6fd8ce03>:2: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df_pehe['selection'] = df_pehe.apply(pehe_filter, axis=1)

# %%
df_merged = df_ate.merge(df_pehe, on=['name'], suffixes=['_ate', '_pehe'])
#df_merged

# %%
print(df_merged[['name', 'selection_ate', 'ate_test', 'selection_pehe', 'pehe_test']].to_latex(index=False, escape=False))
# Out:
# \begin{tabular}{lllll}
# \toprule
#        name &    selection_ate &         ate_test &   selection_pehe &        pehe_test \\
# \midrule
#       SL-L1 &  $1.227\pm2.681$ &  $1.136\pm2.708$ &  $4.426\pm7.334$ &  $4.414\pm7.336$ \\
#       SL-L2 &  $1.243\pm2.723$ &  $1.100\pm2.658$ &  $4.433\pm7.347$ &  $4.405\pm7.317$ \\
#       SL-DT &  $0.397\pm0.643$ &  $0.008\pm0.014$ &  $3.150\pm5.221$ &  $2.487\pm3.842$ \\
#       SL-RF &  $0.269\pm0.457$ &  $0.043\pm0.050$ &  $2.179\pm3.547$ &  $2.153\pm3.558$ \\
#       SL-ET &  $0.241\pm0.337$ &  $0.106\pm0.281$ &  $2.027\pm3.300$ &  $1.911\pm3.247$ \\
#       SL-KR &  $0.292\pm0.279$ &  $0.044\pm0.081$ &  $1.624\pm1.786$ &  $1.369\pm1.675$ \\
#       SL-CB &  $0.319\pm0.140$ &  $0.209\pm0.147$ &  $1.465\pm2.026$ &  $1.322\pm1.875$ \\
#     SL-LGBM &  $0.192\pm0.185$ &  $0.106\pm0.144$ &  $1.845\pm2.949$ &  $1.699\pm2.664$ \\
#       TL-L1 &  $0.461\pm0.450$ &  $0.308\pm0.418$ &  $2.088\pm2.773$ &  $2.057\pm2.785$ \\
#       TL-L2 &  $0.470\pm0.524$ &  $0.349\pm0.519$ &  $2.132\pm2.755$ &  $2.051\pm2.727$ \\
#       TL-DT &  $0.247\pm0.197$ &  $0.000\pm0.001$ &  $2.797\pm4.375$ &  $2.413\pm3.949$ \\
#       TL-RF &  $0.148\pm0.148$ &  $0.065\pm0.119$ &  $1.714\pm2.467$ &  $1.668\pm2.470$ \\
#       TL-ET &  $0.259\pm0.616$ &  $0.103\pm0.305$ &  $1.762\pm2.932$ &  $1.634\pm2.808$ \\
#       TL-KR &  $0.174\pm0.292$ &  $0.008\pm0.015$ &  $0.712\pm0.599$ &  $0.653\pm0.586$ \\
#       TL-CB &  $0.106\pm0.059$ &  $0.030\pm0.040$ &  $0.971\pm1.189$ &  $0.898\pm1.155$ \\
#     TL-LGBM &  $0.199\pm0.205$ &  $0.125\pm0.119$ &  $1.769\pm1.613$ &  $1.683\pm1.531$ \\
#    IPSWS-L1 &  $0.875\pm1.727$ &  $0.525\pm0.948$ &  $4.320\pm7.054$ &  $4.258\pm6.908$ \\
#    IPSWS-L2 &  $0.739\pm1.085$ &  $0.501\pm0.801$ &  $4.303\pm6.920$ &  $4.259\pm6.887$ \\
#    IPSWS-DT &  $0.284\pm0.371$ &  $0.007\pm0.008$ &  $2.775\pm4.284$ &  $2.187\pm3.283$ \\
#    IPSWS-RF &  $0.238\pm0.337$ &  $0.136\pm0.295$ &  $2.061\pm3.361$ &  $2.020\pm3.349$ \\
#    IPSWS-ET &  $0.214\pm0.373$ &  $0.074\pm0.124$ &  $1.936\pm3.094$ &  $1.860\pm3.123$ \\
#    IPSWS-KR &  $0.138\pm0.097$ &  $0.044\pm0.086$ &  $1.726\pm2.158$ &  $1.366\pm1.674$ \\
#    IPSWS-CB &  $0.299\pm0.103$ &  $0.180\pm0.102$ &  $1.460\pm1.939$ &  $1.294\pm1.804$ \\
#  IPSWS-LGBM &  $0.175\pm0.159$ &  $0.101\pm0.148$ &  $1.751\pm2.737$ &  $1.670\pm2.625$ \\
#      DRS-L1 &  $0.914\pm1.726$ &  $0.147\pm0.302$ &  $2.838\pm4.341$ &  $2.229\pm3.914$ \\
#      DRS-L2 &  $0.701\pm1.528$ &  $0.691\pm1.532$ &  $2.229\pm3.500$ &  $2.216\pm3.505$ \\
#      DRS-DT &  $0.514\pm0.772$ &  $0.006\pm0.006$ &  $3.361\pm5.412$ &  $2.775\pm4.377$ \\
#      DRS-RF &  $0.348\pm0.485$ &  $0.125\pm0.182$ &  $2.159\pm3.231$ &  $1.663\pm2.549$ \\
#      DRS-ET &  $0.444\pm1.079$ &  $0.271\pm0.791$ &  $2.240\pm3.556$ &  $1.877\pm3.054$ \\
#      DRS-KR &  $0.185\pm0.121$ &  $0.043\pm0.066$ &  $3.120\pm5.809$ &  $1.847\pm2.364$ \\
#      DRS-CB &  $0.247\pm0.226$ &  $0.030\pm0.048$ &  $1.569\pm1.832$ &  $1.420\pm1.681$ \\
#    DRS-LGBM &  $0.702\pm1.316$ &  $0.359\pm0.896$ &  $5.589\pm5.894$ &  $5.179\pm5.610$ \\
#     DMLS-L1 &  $0.302\pm0.299$ &  $0.130\pm0.100$ &  $1.922\pm2.725$ &  $1.800\pm2.635$ \\
#     DMLS-L2 &  $0.314\pm0.302$ &  $0.269\pm0.306$ &  $1.925\pm2.720$ &  $1.837\pm2.714$ \\
#     DMLS-DT &  $0.836\pm0.905$ &  $0.277\pm0.186$ &  $2.458\pm3.258$ &  $2.036\pm2.737$ \\
#     DMLS-RF &  $0.350\pm0.387$ &  $0.167\pm0.135$ &  $1.919\pm2.759$ &  $1.863\pm2.733$ \\
#     DMLS-ET &  $0.443\pm0.364$ &  $0.132\pm0.115$ &  $2.090\pm2.751$ &  $1.919\pm2.692$ \\
#     DMLS-KR &  $0.371\pm0.424$ &  $0.064\pm0.156$ &  $1.861\pm2.490$ &  $1.721\pm2.495$ \\
#     DMLS-CB &  $0.426\pm0.389$ &  $0.193\pm0.122$ &  $1.981\pm2.657$ &  $1.857\pm2.665$ \\
#   DMLS-LGBM &  $0.510\pm0.391$ &  $0.424\pm0.358$ &  $2.108\pm2.757$ &  $2.004\pm2.640$ \\
#       XL-L1 &  $0.267\pm0.409$ &  $0.157\pm0.298$ &  $1.699\pm2.682$ &  $1.649\pm2.649$ \\
#       XL-L2 &  $0.242\pm0.418$ &  $0.187\pm0.361$ &  $1.808\pm2.703$ &  $1.615\pm2.518$ \\
#       XL-DT &  $0.293\pm0.357$ &  $0.019\pm0.031$ &  $2.859\pm4.382$ &  $2.402\pm3.859$ \\
#       XL-RF &  $0.317\pm0.423$ &  $0.198\pm0.358$ &  $2.331\pm3.560$ &  $2.260\pm3.553$ \\
#       XL-ET &  $0.395\pm0.791$ &  $0.255\pm0.690$ &  $2.411\pm3.569$ &  $2.200\pm3.358$ \\
#       XL-KR &  $0.257\pm0.394$ &  $0.036\pm0.062$ &  $1.234\pm1.343$ &  $1.102\pm1.211$ \\
#       XL-CB &  $0.255\pm0.384$ &  $0.194\pm0.311$ &  $1.665\pm2.274$ &  $1.650\pm2.278$ \\
#     XL-LGBM &  $0.277\pm0.212$ &  $0.143\pm0.176$ &  $2.661\pm3.515$ &  $2.505\pm3.240$ \\
#          CF &  $0.240\pm0.388$ &  $0.198\pm0.392$ &  $2.295\pm3.556$ &  $2.290\pm3.559$ \\
#      SL-MLP &  $0.486\pm0.385$ &  $0.104\pm0.113$ &  $1.064\pm0.637$ &  $0.925\pm0.673$ \\
#      TL-MLP &  $0.221\pm0.229$ &  $0.000\pm0.000$ &  $0.894\pm0.549$ &  $0.641\pm0.570$ \\
# \bottomrule
# \end{tabular}

# %% [markdown]
# ## JOBS

# %%
plugin_meta_models = ['sl', 'tl']
#plugin_base_models = ['dt', 'lgbm']
plugin_base_models = ['lgbm']
plugin_models = [f'{pmm}_{pbm}' for pmm in plugin_meta_models for pbm in plugin_base_models]
#rscore_base_models = ['dt', 'lgbm', 'cb']
rscore_base_models = ['lgbm']

ds = 'jobs'
df_all = pd.read_csv(f'./tables/{ds}_compare_metrics_latex.csv')
avg_metric = 'att'
ite_metric = 'policy'

df_all['name'] = df_all['name'].apply(lambda x: x.upper().replace('_', '-'))

# %%
df_att = show(df_all, avg_metric, 'ate', plugin_models, rscore_base_models)
df_pol = show(df_all, ite_metric, 'pehe', plugin_models, rscore_base_models)
#df

# %%
df_att['selection'] = df_att.apply(att_filter, axis=1)
df_pol['selection'] = df_pol.apply(policy_filter, axis=1)
# Out:
# <ipython-input-11-0894e227694b>:1: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df_att['selection'] = df_att.apply(att_filter, axis=1)
# <ipython-input-11-0894e227694b>:2: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df_pol['selection'] = df_pol.apply(policy_filter, axis=1)

# %%
df_merged = df_att.merge(df_pol, on=['name'], suffixes=['_att', '_pol'])
#df_merged

# %%
print(df_merged[['name', 'selection_att', 'att_test', 'selection_pol', 'policy_test']].to_latex(index=False, escape=False))
# Out:
# \begin{tabular}{lllll}
# \toprule
#        name &    selection_att &         att_test &    selection_pol &      policy_test \\
# \midrule
#       SL-L1 &  $0.071\pm0.080$ &  $0.060\pm0.080$ &  $0.241\pm0.044$ &  $0.220\pm0.047$ \\
#       SL-L2 &  $0.079\pm0.072$ &  $0.075\pm0.073$ &  $0.226\pm0.049$ &  $0.226\pm0.049$ \\
#       SL-DT &  $0.069\pm0.080$ &  $0.025\pm0.046$ &  $0.292\pm0.068$ &  $0.225\pm0.049$ \\
#       SL-RF &  $0.075\pm0.077$ &  $0.050\pm0.067$ &  $0.249\pm0.055$ &  $0.197\pm0.045$ \\
#       SL-ET &  $0.070\pm0.060$ &  $0.043\pm0.060$ &  $0.267\pm0.063$ &  $0.172\pm0.041$ \\
#       SL-KR &  $0.081\pm0.068$ &  $0.008\pm0.009$ &  $0.238\pm0.041$ &  $0.166\pm0.033$ \\
#       SL-CB &  $0.076\pm0.069$ &  $0.059\pm0.068$ &  $0.247\pm0.052$ &  $0.185\pm0.036$ \\
#     SL-LGBM &  $0.067\pm0.070$ &  $0.057\pm0.070$ &  $0.202\pm0.045$ &  $0.184\pm0.039$ \\
#       TL-L1 &  $0.074\pm0.069$ &  $0.049\pm0.070$ &  $0.246\pm0.047$ &  $0.222\pm0.044$ \\
#       TL-L2 &  $0.077\pm0.074$ &  $0.068\pm0.070$ &  $0.238\pm0.048$ &  $0.227\pm0.052$ \\
#       TL-DT &  $0.059\pm0.064$ &  $0.014\pm0.029$ &  $0.246\pm0.052$ &  $0.149\pm0.032$ \\
#       TL-RF &  $0.067\pm0.061$ &  $0.040\pm0.062$ &  $0.239\pm0.048$ &  $0.169\pm0.047$ \\
#       TL-ET &  $0.074\pm0.068$ &  $0.032\pm0.051$ &  $0.234\pm0.053$ &  $0.150\pm0.041$ \\
#       TL-KR &  $0.079\pm0.066$ &  $0.000\pm0.000$ &  $0.230\pm0.059$ &  $0.142\pm0.026$ \\
#       TL-CB &  $0.072\pm0.060$ &  $0.049\pm0.061$ &  $0.207\pm0.044$ &  $0.164\pm0.035$ \\
#     TL-LGBM &  $0.095\pm0.060$ &  $0.079\pm0.061$ &  $0.223\pm0.047$ &  $0.196\pm0.038$ \\
#      DRS-L1 &  $0.077\pm0.067$ &  $0.056\pm0.062$ &  $0.245\pm0.045$ &  $0.243\pm0.043$ \\
#      DRS-L2 &  $0.077\pm0.076$ &  $0.075\pm0.075$ &  $0.247\pm0.042$ &  $0.242\pm0.044$ \\
#      DRS-DT &  $0.072\pm0.049$ &  $0.003\pm0.003$ &  $0.254\pm0.039$ &  $0.168\pm0.030$ \\
#      DRS-RF &  $0.073\pm0.060$ &  $0.021\pm0.031$ &  $0.235\pm0.043$ &  $0.185\pm0.044$ \\
#      DRS-ET &  $0.075\pm0.069$ &  $0.028\pm0.040$ &  $0.240\pm0.029$ &  $0.172\pm0.038$ \\
#      DRS-KR &  $0.077\pm0.071$ &  $0.005\pm0.005$ &  $0.251\pm0.050$ &  $0.162\pm0.037$ \\
#      DRS-CB &  $0.072\pm0.069$ &  $0.035\pm0.036$ &  $0.212\pm0.047$ &  $0.169\pm0.035$ \\
#    DRS-LGBM &  $0.108\pm0.078$ &  $0.016\pm0.027$ &  $0.232\pm0.038$ &  $0.197\pm0.035$ \\
#     DMLS-L1 &  $0.076\pm0.069$ &  $0.054\pm0.072$ &  $0.255\pm0.046$ &  $0.243\pm0.048$ \\
#     DMLS-L2 &  $0.075\pm0.069$ &  $0.073\pm0.069$ &  $0.250\pm0.044$ &  $0.248\pm0.043$ \\
#     DMLS-DT &  $0.078\pm0.067$ &  $0.047\pm0.066$ &  $0.250\pm0.048$ &  $0.210\pm0.040$ \\
#     DMLS-RF &  $0.077\pm0.068$ &  $0.071\pm0.070$ &  $0.260\pm0.040$ &  $0.244\pm0.048$ \\
#     DMLS-ET &  $0.078\pm0.069$ &  $0.067\pm0.069$ &  $0.264\pm0.043$ &  $0.243\pm0.043$ \\
#     DMLS-KR &  $0.077\pm0.070$ &  $0.016\pm0.016$ &  $0.253\pm0.043$ &  $0.195\pm0.036$ \\
#     DMLS-CB &  $0.081\pm0.068$ &  $0.075\pm0.069$ &  $0.256\pm0.051$ &  $0.232\pm0.038$ \\
#   DMLS-LGBM &  $0.084\pm0.070$ &  $0.070\pm0.070$ &  $0.250\pm0.045$ &  $0.234\pm0.041$ \\
#       XL-L1 &  $0.119\pm0.108$ &  $0.057\pm0.069$ &  $0.270\pm0.075$ &  $0.233\pm0.048$ \\
#       XL-L2 &  $0.078\pm0.068$ &  $0.071\pm0.071$ &  $0.237\pm0.051$ &  $0.229\pm0.050$ \\
#       XL-DT &  $0.073\pm0.076$ &  $0.031\pm0.053$ &  $0.234\pm0.063$ &  $0.158\pm0.039$ \\
#       XL-RF &  $0.075\pm0.068$ &  $0.043\pm0.070$ &  $0.223\pm0.043$ &  $0.184\pm0.048$ \\
#       XL-ET &  $0.078\pm0.064$ &  $0.047\pm0.058$ &  $0.227\pm0.046$ &  $0.175\pm0.042$ \\
#       XL-KR &  $0.078\pm0.069$ &  $0.010\pm0.014$ &  $0.218\pm0.057$ &  $0.165\pm0.031$ \\
#       XL-CB &  $0.072\pm0.070$ &  $0.058\pm0.067$ &  $0.215\pm0.048$ &  $0.184\pm0.035$ \\
#     XL-LGBM &  $0.085\pm0.066$ &  $0.072\pm0.060$ &  $0.229\pm0.048$ &  $0.205\pm0.041$ \\
#    IPSWS-L1 &  $0.083\pm0.079$ &  $0.055\pm0.083$ &  $0.298\pm0.060$ &  $0.249\pm0.076$ \\
#    IPSWS-L2 &  $0.086\pm0.075$ &  $0.084\pm0.075$ &  $0.226\pm0.049$ &  $0.226\pm0.049$ \\
#    IPSWS-DT &  $0.084\pm0.081$ &  $0.024\pm0.056$ &  $0.291\pm0.061$ &  $0.193\pm0.049$ \\
#    IPSWS-RF &  $0.077\pm0.075$ &  $0.047\pm0.069$ &  $0.245\pm0.038$ &  $0.180\pm0.048$ \\
#    IPSWS-CB &  $0.074\pm0.061$ &  $0.053\pm0.067$ &  $0.238\pm0.044$ &  $0.191\pm0.039$ \\
#  IPSWS-LGBM &  $0.078\pm0.071$ &  $0.067\pm0.073$ &  $0.211\pm0.045$ &  $0.189\pm0.038$ \\
#          CF &  $0.072\pm0.064$ &  $0.053\pm0.067$ &  $0.225\pm0.047$ &  $0.204\pm0.050$ \\
#      SL-MLP &  $0.068\pm0.066$ &  $0.023\pm0.057$ &  $0.254\pm0.055$ &  $0.162\pm0.029$ \\
#      TL-MLP &  $0.066\pm0.078$ &  $0.010\pm0.029$ &  $0.226\pm0.041$ &  $0.132\pm0.028$ \\
# \bottomrule
# \end{tabular}

# %%
df = show(df_all, avg_metric, 'pehe', plugin_models, rscore_base_models)
df
# Out:
#      name          att_mse           att_r2        att_mixed   att_sl_dt_pehe  \
# 0      sl  0.066 +/- 0.060  0.076 +/- 0.061                -  0.083 +/- 0.079
# 1      tl  0.074 +/- 0.069  0.077 +/- 0.067                -  0.138 +/- 0.090
# 2   ipsws  0.077 +/- 0.075  0.080 +/- 0.073                -  0.083 +/- 0.079
# 3     drs                -                -  0.075 +/- 0.069  0.102 +/- 0.067
# 4    dmls                -                -  0.078 +/- 0.070  0.083 +/- 0.079
# 5      xl                -                -                -  0.076 +/- 0.075
# 6      cf                -                -                -  0.074 +/- 0.069
# 7  sl_mlp  0.068 +/- 0.066  0.071 +/- 0.065                -  0.071 +/- 0.086
# 8  tl_mlp  0.066 +/- 0.078  0.075 +/- 0.074                -  0.098 +/- 0.090
#
#   att_sl_lgbm_pehe   att_tl_dt_pehe att_tl_lgbm_pehe        att_rs_dt  \
# 0  0.083 +/- 0.079  0.063 +/- 0.069  0.075 +/- 0.070  0.079 +/- 0.071
# 1  0.137 +/- 0.092  0.070 +/- 0.061  0.071 +/- 0.065  0.070 +/- 0.075
# 2  0.083 +/- 0.079  0.071 +/- 0.057  0.068 +/- 0.075  0.075 +/- 0.063
# 3  0.105 +/- 0.065  0.094 +/- 0.077  0.095 +/- 0.075  0.065 +/- 0.059
# 4  0.083 +/- 0.079  0.086 +/- 0.073  0.087 +/- 0.066  0.090 +/- 0.072
# 5  0.076 +/- 0.075  0.081 +/- 0.075  0.075 +/- 0.078  0.073 +/- 0.064
# 6  0.079 +/- 0.067  0.075 +/- 0.068  0.076 +/- 0.068  0.072 +/- 0.064
# 7  0.087 +/- 0.081  0.064 +/- 0.074  0.063 +/- 0.067  0.075 +/- 0.068
# 8  0.081 +/- 0.081  0.087 +/- 0.077  0.086 +/- 0.087  0.078 +/- 0.052
#
#        att_rs_lgbm        att_rs_cb         att_test
# 0  0.076 +/- 0.070  0.074 +/- 0.068  0.003 +/- 0.004
# 1  0.081 +/- 0.074  0.074 +/- 0.056  0.000 +/- 0.000
# 2  0.079 +/- 0.059  0.076 +/- 0.065  0.024 +/- 0.056
# 3  0.064 +/- 0.058  0.070 +/- 0.067  0.001 +/- 0.002
# 4  0.107 +/- 0.092  0.088 +/- 0.073  0.016 +/- 0.016
# 5  0.077 +/- 0.074  0.067 +/- 0.069  0.003 +/- 0.007
# 6  0.072 +/- 0.064  0.072 +/- 0.064  0.053 +/- 0.067
# 7  0.075 +/- 0.076  0.071 +/- 0.072  0.023 +/- 0.057
# 8  0.088 +/- 0.074  0.065 +/- 0.061  0.010 +/- 0.029

# %%
df[['name', f'{avg_metric}_mse', f'{avg_metric}_r2', f'{avg_metric}_mixed', f'{avg_metric}_test']]
# Out:
#      name          att_mse           att_r2        att_mixed         att_test
# 0      sl  0.066 +/- 0.060  0.076 +/- 0.061                -  0.003 +/- 0.004
# 1      tl  0.074 +/- 0.069  0.077 +/- 0.067                -  0.000 +/- 0.000
# 2   ipsws  0.077 +/- 0.075  0.080 +/- 0.073                -  0.024 +/- 0.056
# 3     drs                -                -  0.075 +/- 0.069  0.001 +/- 0.002
# 4    dmls                -                -  0.078 +/- 0.070  0.016 +/- 0.016
# 5      xl                -                -                -  0.003 +/- 0.007
# 6      cf                -                -                -  0.053 +/- 0.067
# 7  sl_mlp  0.068 +/- 0.066  0.071 +/- 0.065                -  0.023 +/- 0.057
# 8  tl_mlp  0.066 +/- 0.078  0.075 +/- 0.074                -  0.010 +/- 0.029

# %%
df = show(df_all, ite_metric, 'pehe', plugin_models, rscore_base_models)
df
# Out:
#      name       policy_mse        policy_r2     policy_mixed  \
# 0      sl  0.261 +/- 0.057  0.262 +/- 0.063                -
# 1      tl  0.235 +/- 0.058  0.237 +/- 0.055                -
# 2   ipsws  0.245 +/- 0.038  0.245 +/- 0.033                -
# 3     drs                -                -  0.240 +/- 0.029
# 4    dmls                -                -  0.264 +/- 0.043
# 5      xl                -                -                -
# 6      cf                -                -                -
# 7  sl_mlp  0.254 +/- 0.055  0.257 +/- 0.052                -
# 8  tl_mlp  0.226 +/- 0.041  0.248 +/- 0.067                -
#
#   policy_sl_dt_pehe policy_sl_lgbm_pehe policy_tl_dt_pehe policy_tl_lgbm_pehe  \
# 0   0.297 +/- 0.060     0.297 +/- 0.060   0.242 +/- 0.059     0.247 +/- 0.056
# 1   0.284 +/- 0.042     0.282 +/- 0.042   0.251 +/- 0.047     0.257 +/- 0.045
# 2   0.296 +/- 0.060     0.297 +/- 0.060   0.241 +/- 0.065     0.229 +/- 0.046
# 3   0.265 +/- 0.051     0.264 +/- 0.051   0.253 +/- 0.040     0.261 +/- 0.044
# 4   0.293 +/- 0.061     0.293 +/- 0.061   0.277 +/- 0.069     0.255 +/- 0.047
# 5   0.218 +/- 0.033     0.218 +/- 0.033   0.249 +/- 0.053     0.251 +/- 0.048
# 6   0.250 +/- 0.052     0.254 +/- 0.051   0.256 +/- 0.060     0.258 +/- 0.057
# 7   0.277 +/- 0.082     0.273 +/- 0.093   0.255 +/- 0.040     0.251 +/- 0.045
# 8   0.269 +/- 0.074     0.246 +/- 0.063   0.257 +/- 0.037     0.243 +/- 0.047
#
#       policy_rs_dt   policy_rs_lgbm     policy_rs_cb      policy_test
# 0  0.246 +/- 0.048  0.211 +/- 0.037  0.217 +/- 0.045  0.158 +/- 0.034
# 1  0.236 +/- 0.052  0.241 +/- 0.047  0.217 +/- 0.032  0.128 +/- 0.036
# 2  0.271 +/- 0.048  0.248 +/- 0.058  0.251 +/- 0.046  0.158 +/- 0.038
# 3  0.236 +/- 0.035  0.243 +/- 0.046  0.235 +/- 0.050  0.149 +/- 0.030
# 4  0.248 +/- 0.039  0.271 +/- 0.062  0.238 +/- 0.043  0.193 +/- 0.035
# 5  0.218 +/- 0.034  0.233 +/- 0.057  0.220 +/- 0.052  0.153 +/- 0.038
# 6  0.226 +/- 0.040  0.225 +/- 0.047  0.225 +/- 0.048  0.204 +/- 0.050
# 7  0.238 +/- 0.052  0.251 +/- 0.042  0.242 +/- 0.036  0.162 +/- 0.029
# 8  0.218 +/- 0.040  0.216 +/- 0.046  0.220 +/- 0.041  0.132 +/- 0.028

# %%
df[['name', f'{ite_metric}_mse', f'{ite_metric}_r2', f'{ite_metric}_mixed', f'{ite_metric}_test']]
# Out:
#      name       policy_mse        policy_r2     policy_mixed      policy_test
# 0      sl  0.261 +/- 0.057  0.262 +/- 0.063                -  0.158 +/- 0.034
# 1      tl  0.235 +/- 0.058  0.237 +/- 0.055                -  0.128 +/- 0.036
# 2   ipsws  0.245 +/- 0.038  0.245 +/- 0.033                -  0.158 +/- 0.038
# 3     drs                -                -  0.240 +/- 0.029  0.149 +/- 0.030
# 4    dmls                -                -  0.264 +/- 0.043  0.193 +/- 0.035
# 5      xl                -                -                -  0.153 +/- 0.038
# 6      cf                -                -                -  0.204 +/- 0.050
# 7  sl_mlp  0.254 +/- 0.055  0.257 +/- 0.052                -  0.162 +/- 0.029
# 8  tl_mlp  0.226 +/- 0.041  0.248 +/- 0.067                -  0.132 +/- 0.028
