# %%
import pandas as pd

plugin_meta_models = ['sl', 'tl']
plugin_base_models = ['dt', 'lgbm', 'cb']
plugin_models = [f'{pmm}_{pbm}' for pmm in plugin_meta_models for pbm in plugin_base_models]
rscore_base_models = ['dt', 'lgbm', 'cb']

df_all = pd.read_csv('./tables/compare_correlations.csv')

# %%
metric = 'ate'
p_metric = 'pehe'
plugin_cols = [f'{metric}_{pm}_{p_metric}' for pm in plugin_models]
rscore_cols = [f'{metric}_rs_{rs_bm}' for rs_bm in rscore_base_models]
cols = ['name', f'{metric}_mse', f'{metric}_r2'] + plugin_cols + rscore_cols
df_all[cols]
# Out:
#        name           ate_mse  ...       ate_rs_lgbm         ate_rs_cb
# 0     sl_l1  -0.978 +/- 0.023  ...  -0.986 +/- 0.005  -0.980 +/- 0.009
# 1     sl_l2  -0.787 +/- 0.597  ...  -0.671 +/- 0.566   0.524 +/- 0.619
# 2     sl_dt   0.130 +/- 0.427  ...  -0.038 +/- 0.319  -0.039 +/- 0.326
# 3     sl_rf  -0.033 +/- 0.492  ...  -0.161 +/- 0.415  -0.152 +/- 0.401
# 4     sl_et  -0.069 +/- 0.591  ...  -0.010 +/- 0.584  -0.124 +/- 0.578
# 5     sl_kr  -0.708 +/- 0.130  ...  -0.946 +/- 0.059  -0.924 +/- 0.103
# 6     sl_cb  -0.942 +/- 0.083  ...  -0.839 +/- 0.173  -0.085 +/- 0.619
# 7   sl_lgbm  -0.017 +/- 0.285  ...   0.115 +/- 0.305  -0.024 +/- 0.388
# 8     tl_l1   0.806 +/- 0.335  ...  -0.819 +/- 0.307  -0.786 +/- 0.316
# 9     tl_l2  -0.397 +/- 0.412  ...   0.067 +/- 0.716   0.397 +/- 0.719
# 10    tl_dt   0.201 +/- 0.295  ...  -0.117 +/- 0.304  -0.147 +/- 0.275
# 11    tl_rf   0.384 +/- 0.476  ...  -0.333 +/- 0.461  -0.389 +/- 0.473
# 12    tl_et   0.209 +/- 0.432  ...  -0.151 +/- 0.397  -0.211 +/- 0.418
# 13    tl_kr   0.729 +/- 0.261  ...  -0.777 +/- 0.215  -0.676 +/- 0.212
# 14    tl_cb   0.193 +/- 0.452  ...  -0.148 +/- 0.481  -0.145 +/- 0.455
# 15  tl_lgbm   0.165 +/- 0.192  ...  -0.095 +/- 0.285  -0.030 +/- 0.267
# 16       cf                 -  ...  -0.377 +/- 0.409  -0.389 +/- 0.461
#
# [17 rows x 12 columns]

# %%
metric = 'pehe'
p_metric = 'pehe'
plugin_cols = [f'{metric}_{pm}_{p_metric}' for pm in plugin_models]
rscore_cols = [f'{metric}_rs_{rs_bm}' for rs_bm in rscore_base_models]
cols = ['name', f'{metric}_mse', f'{metric}_r2'] + plugin_cols + rscore_cols
df_all[cols]
# Out:
#        name          pehe_mse  ...      pehe_rs_lgbm        pehe_rs_cb
# 0     sl_l1  -0.970 +/- 0.019  ...  -0.994 +/- 0.003  -0.990 +/- 0.005
# 1     sl_l2  -0.779 +/- 0.593  ...  -0.710 +/- 0.570   0.467 +/- 0.610
# 2     sl_dt   0.884 +/- 0.090  ...  -0.338 +/- 0.599  -0.290 +/- 0.609
# 3     sl_rf   0.792 +/- 0.311  ...   0.534 +/- 0.519   0.534 +/- 0.455
# 4     sl_et   0.909 +/- 0.096  ...   0.503 +/- 0.515   0.564 +/- 0.490
# 5     sl_kr  -0.287 +/- 0.551  ...  -0.610 +/- 0.682  -0.590 +/- 0.683
# 6     sl_cb  -0.528 +/- 0.656  ...  -0.493 +/- 0.654   0.240 +/- 0.524
# 7   sl_lgbm   0.081 +/- 0.271  ...  -0.125 +/- 0.415  -0.189 +/- 0.554
# 8     tl_l1   0.571 +/- 0.720  ...  -0.595 +/- 0.705  -0.559 +/- 0.700
# 9     tl_l2   0.175 +/- 0.709  ...  -0.480 +/- 0.529  -0.537 +/- 0.441
# 10    tl_dt   0.272 +/- 0.600  ...  -0.306 +/- 0.534  -0.267 +/- 0.497
# 11    tl_rf  -0.593 +/- 0.368  ...   0.551 +/- 0.387   0.500 +/- 0.481
# 12    tl_et  -0.631 +/- 0.453  ...   0.413 +/- 0.510   0.513 +/- 0.449
# 13    tl_kr   0.488 +/- 0.662  ...  -0.524 +/- 0.677  -0.469 +/- 0.645
# 14    tl_cb  -0.559 +/- 0.514  ...   0.317 +/- 0.553   0.528 +/- 0.424
# 15  tl_lgbm   0.032 +/- 0.323  ...  -0.160 +/- 0.169  -0.066 +/- 0.285
# 16       cf                 -  ...   0.608 +/- 0.504   0.595 +/- 0.422
#
# [17 rows x 12 columns]
